# %%
import ifcopenshell
from topologicpy.Topology import Topology
from topologicpy.Dictionary import Dictionary

# Beispielhafte Nutzung
ifc_file_path = '../Hus28_test.ifc'
storey_name = 'Plan 10'

# IFC-Datei öffnen
ifc_file = ifcopenshell.open(ifc_file_path)
print("IFC file opened successfully.")

# Liste, um die GUIDs der Wände im angegebenen Geschoss zu speichern
guids_in_storey = []

# Durchlaufen aller IfcWall-Objekte und deren Beziehungen
for wall in ifc_file.by_type('IfcWall'):
    for rel in ifc_file.by_type("IfcRelContainedInSpatialStructure"):
        if wall in rel.RelatedElements:
            storey = rel.RelatingStructure
            if storey and storey.Name == storey_name:
                guids_in_storey.append(wall.GlobalId)
                break

print(f"Found {len(guids_in_storey)} GUIDs in storey '{storey_name}'.")

# Laden der IFC-Datei
ifc_file = ifcopenshell.open(ifc_file_path)
print("IFC file opened successfully.")

# Erstellen der Topologien aller Wände im IFC-Modell
wall_topologies = Topology.ByIFCFile(file=ifc_file, transferDictionaries=True, includeTypes=['IfcWall'])
print("Initial wall topologies created successfully.")

# Filtern der Topologien nach GUIDs der Wände im Geschoss
walls_in_storey = []

for topo in wall_topologies:
    topo_dict = Topology.Dictionary(topo)
    topo_guid = Dictionary.ValueAtKey(topo_dict, "IFC_guid")
    if topo_guid in guids_in_storey:
        walls_in_storey.append(topo)

print(f"Found {len(walls_in_storey)} wall topologies in storey '{storey_name}'.")
# Out:
# IFC file opened successfully.
# Found 138 GUIDs in storey 'Plan 10'.
# IFC file opened successfully.
# Initial wall topologies created successfully.
# Found 138 wall topologies in storey 'Plan 10'.

# %%
import re

def filter_ifcspaces_by_storey(spaces, storey_name):
    filtered_spaces = []
    for space in spaces:
        for rel in space.Decomposes:
            if rel.is_a("IfcRelAggregates") and rel.RelatingObject.is_a("IfcBuildingStorey"):
                if rel.RelatingObject.Name == storey_name:
                    filtered_spaces.append(space)
                    break
    return filtered_spaces

def filter_spaces_by_name(spaces):
    digit_pattern = re.compile(r'^\d{1,5}$')
    filtered_spaces = []
    for space in spaces:
        if digit_pattern.match(space.Name):
            filtered_spaces.append(space)
    return filtered_spaces

# Alle IfcSpaces einlesen
spaces = ifc_file.by_type('IfcSpace')

# Nach Stockwerk filtern
spaces_in_storey = filter_ifcspaces_by_storey(spaces, storey_name)
print(f"Filtered {len(spaces_in_storey)} IfcSpaces in storey '{storey_name}'.")

# Nach Namen filtern
filtered_spaces = filter_spaces_by_name(spaces_in_storey)
print(f"Filtered {len(filtered_spaces)} IfcSpaces with valid names.")
# Out:
# Filtered 37 IfcSpaces in storey 'Plan 10'.
# Filtered 30 IfcSpaces with valid names.

# %%
# Erstellen der Topologien aller gefilterten Räume im IFC-Modell
space_topologies = Topology.ByIFCFile(file=ifc_file, transferDictionaries=True, includeTypes=['IfcSpace'])
print("Initial space topologies created successfully.")

# Filtern der Topologien nach den gefilterten Räumen
spaces_in_storey = []

for topo in space_topologies:
    topo_dict = Topology.Dictionary(topo)
    topo_guid = Dictionary.ValueAtKey(topo_dict, "IFC_guid")
    if any(space.GlobalId == topo_guid for space in filtered_spaces):
        spaces_in_storey.append(topo)

print(f"Found {len(spaces_in_storey)} space topologies in storey '{storey_name}' with valid names.")
# Out:
# Initial space topologies created successfully.
# Found 30 space topologies in storey 'Plan 10' with valid names.

# %%
# Wall Topologies
print(len(walls_in_storey))

# Wall Topologies
print(len(spaces_in_storey))

# Wall Guids
print(len(guids_in_storey))
# Out:
# 138
# 30
# 138

# %%
from neo4j import GraphDatabase

# Verbindung zur Neo4J-Datenbank herstellen
uri = "bolt://localhost:7687"  # Standardadresse für Neo4J
username = "neo4j"
password = "testpass"
driver = GraphDatabase.driver(uri, auth=(username, password))

def create_wall_nodes(driver, topologies):
    with driver.session() as session:
        for topo in topologies:
            topo_dict = Topology.Dictionary(topo)
            topo_guid = Dictionary.ValueAtKey(topo_dict, "IFC_guid")
            wall_name = Dictionary.ValueAtKey(topo_dict, "IFC_Name")
            wall_type = Dictionary.ValueAtKey(topo_dict, "IFC_Type")
            
            # Erstellen des Cypher-Statements
            cypher_query = """
            MERGE (w:Wall {guid: $guid})
            SET w.name = $name, w.type = $type
            """
            session.run(cypher_query, guid=topo_guid, name=wall_name, type=wall_type)
            print(f"Wall node with GUID {topo_guid} created or updated.")

# Wall Nodes in der Datenbank anlegen
create_wall_nodes(driver, walls_in_storey)
# Out:
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSdZ created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSdx created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSdk created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSdq created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSda created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nScE created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSdY created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nScD created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSc6 created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSdj created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nScR created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSdW created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSc7 created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSdt created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSd$ created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nScJ created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nScV created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nScI created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSc8 created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSc2 created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSdi created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSer created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSet created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSes created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSeq created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nShA created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nShB created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSHR created or updated.
# Wall node with GUID 0aNC3YsFzEZf8uB9g1nSHQ created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1pP created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1pd created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1pQ created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1pO created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1pJ created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1pD created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1pE created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1pF created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1p0 created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1oj created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1oi created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1ob created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1oT created or updated.
# Wall node with GUID 3V7W2RscLEExyQLuCnt1oV created or updated.
# Wall node with GUID 3V4w8SHAjCyBUTFZ8uhZV9 created or updated.
# Wall node with GUID 3V4w8SHAjCyBUTFZ8uhZV8 created or updated.
# Wall node with GUID 3V4w8SHAjCyBUTFZ8uhZ2e created or updated.
# Wall node with GUID 3V4w8SHAjCyBUTFZ8uhZAP created or updated.
# Wall node with GUID 3V4w8SHAjCyBUTFZ8uhZox created or updated.
# Wall node with GUID 3jY3$PuNP3MgMUTrsNt4PV created or updated.
# Wall node with GUID 3R2MGTuSfBAR6UB$SwSzdt created or updated.
# Wall node with GUID 3R2MGTuSfBAR6UB$SwSzz0 created or updated.
# Wall node with GUID 3eHzf38IP4NBm_82GTLjrw created or updated.
# Wall node with GUID 3KZQXY$LH1CRfttEb6cves created or updated.
# Wall node with GUID 21UIHKuuP16uj5JCg0qyOs created or updated.
# Wall node with GUID 0XqmV6lT93V9A_AtAupESF created or updated.
# Wall node with GUID 0XqmV6lT93V9A_AtAupESC created or updated.
# Wall node with GUID 3bmsvJtpP2Lw7375p3CrYk created or updated.
# Wall node with GUID 33WdFHulr6YhyCfaqbl1_4 created or updated.
# Wall node with GUID 0MhF3zuEzBXwC_J$8wDDII created or updated.
# Wall node with GUID 0MhF3zuEzBXwC_J$8wDDGK created or updated.
# Wall node with GUID 0MhF3zuEzBXwC_J$8wDDMj created or updated.
# Wall node with GUID 0MhF3zuEzBXwC_J$8wDFXU created or updated.
# Wall node with GUID 0MhF3zuEzBXwC_J$8wDFXT created or updated.
# Wall node with GUID 3cYPoAMk90vxvLVMNmmhA4 created or updated.
# Wall node with GUID 3cYPoAMk90vxvLVMNmmhA6 created or updated.
# Wall node with GUID 3cYPoAMk90vxvLVMNmmhA7 created or updated.
# Wall node with GUID 1Xdhl_99H1LxtFe91ySc9n created or updated.
# Wall node with GUID 0HLErpwlH7GPXIOwElk89Q created or updated.
# Wall node with GUID 1Xdhl_99H1LxtFe91ySc9m created or updated.
# Wall node with GUID 1Xdhl_99H1LxtFe91ySc9p created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4re created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4rf created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4qK created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4rl created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4rk created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4q6 created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4qC created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4qD created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4qW created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4qX created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4tE created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4tC created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4tB created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4tj created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4tk created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4ti created or updated.
# Wall node with GUID 3xDiDpx$nB2hLMfVxR_vR1 created or updated.
# Wall node with GUID 3xDiDpx$nB2hLMfVxR_vR0 created or updated.
# Wall node with GUID 3xDiDpx$nB2hLMfVxR_vR3 created or updated.
# Wall node with GUID 2_G3CYmpjD1R88WI3Xz4ql created or updated.
# Wall node with GUID 3xDiDpx$nB2hLMfVxR_vLB created or updated.
# Wall node with GUID 3xDiDpx$nB2hLMfVxR_vR2 created or updated.
# Wall node with GUID 1iMxTVpcb2rhU2MxNV6tfy created or updated.
# Wall node with GUID 1iMxTVpcb2rhU2MxNV6toJ created or updated.
# Wall node with GUID 2V0bmays95pR3l2kZG47va created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAc$Gt created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAc$H9 created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAc$Gp created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAc$QO created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAc$Ui created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAcyZu created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAc$Gn created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAcyGD created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAcyOK created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAcyD9 created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAczWd created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAczLp created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAc$2V created or updated.
# Wall node with GUID 0JwH4ZBer9exdsW3Xs1$At created or updated.
# Wall node with GUID 0JwH4ZBer9exdsW3Xs1_wG created or updated.
# Wall node with GUID 1WQPFqcij6iRfftGTAcy7r created or updated.
# Wall node with GUID 2eAZvXReD5rxCsRcBVQwvx created or updated.
# Wall node with GUID 2eAZvXReD5rxCsRcBVQwxO created or updated.
# Wall node with GUID 0JwH4ZBer9exdsW3Xs1_zO created or updated.
# Wall node with GUID 0pyqDFj1b8ou1XMGj0fk5w created or updated.
# Wall node with GUID 0pyqDFj1b8ou1XMGj0fk5y created or updated.
# Wall node with GUID 0pyqDFj1b8ou1XMGj0fk3a created or updated.
# Wall node with GUID 0pyqDFj1b8ou1XMGj0ffLi created or updated.
# Wall node with GUID 0MXhwXpTnD5winnseqQxo0 created or updated.
# Wall node with GUID 169UR4u8f5IfysrZg_pJqq created or updated.
# Wall node with GUID 2cZ6AGv1n9$PsnxX3G51og created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXin created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXit created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXir created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXis created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXim created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXjB created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXiq created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXj9 created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXjA created or updated.
# Wall node with GUID 2aZ_Dto7fDbevo$VG0HXj8 created or updated.
# Wall node with GUID 0FhCwfW0b4_fS3V96JxZJx created or updated.
# Wall node with GUID 0FhCwfW0b4_fS3V96JxZGG created or updated.
# Wall node with GUID 1qLd$aRfnB58C7GyIrSs_g created or updated.
# Wall node with GUID 1qLd$aRfnB58C7GyIrSs$l created or updated.
# Wall node with GUID 1qLd$aRfnB58C7GyIrSsmo created or updated.
# Wall node with GUID 1qLd$aRfnB58C7GyIrSsor created or updated.
# Wall node with GUID 3xcRif4sv86voAEI35bpCh created or updated.

# %%
# Funktion zum Erstellen von Raum-Nodes in Neo4J
def create_room_nodes(driver, space_topologies):
    with driver.session() as session:
        for topo in space_topologies:
            topo_dict = Topology.Dictionary(topo)
            room_guid = Dictionary.ValueAtKey(topo_dict, "IFC_guid")
            room_name = Dictionary.ValueAtKey(topo_dict, "IFC_Name")
            
            # Erstellen des Raum-Nodes
            cypher_query = """
            MERGE (r:Room {guid: $room_guid})
            SET r.name = $room_name
            """
            session.run(cypher_query, room_guid=room_guid, room_name=room_name)
            print(f"Room node with GUID {room_guid} created or updated.")

# Räume in der Neo4J-Datenbank anlegen
create_room_nodes(driver, spaces_in_storey)
# Out:
# Room node with GUID 0uSXiavKjD892bcKOjMA$f created or updated.
# Room node with GUID 0uSXiavKjD892bcKOjMA$x created or updated.
# Room node with GUID 2Im_2tj0r41BcHdJK8Kcz3 created or updated.
# Room node with GUID 0uSXiavKjD892bcKOjMA$i created or updated.
# Room node with GUID 0uSXiavKjD892bcKOjMA$4 created or updated.
# Room node with GUID 0uSXiavKjD892bcKOjMA$1 created or updated.
# Room node with GUID 0aNC3YsFzEZf8uB9g1nSca created or updated.
# Room node with GUID 0aNC3YsFzEZf8uB9g1nSfQ created or updated.
# Room node with GUID 0aNC3YsFzEZf8uB9g1nScw created or updated.
# Room node with GUID 0aNC3YsFzEZf8uB9g1nScx created or updated.
# Room node with GUID 0aNC3YsFzEZf8uB9g1nScv created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1p6 created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1ow created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1ox created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1oy created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1o$ created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1o_ created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1oJ created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1om created or updated.
# Room node with GUID 2_G3CYmpjD1R88WI3Xz4qo created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1oz created or updated.
# Room node with GUID 2_G3CYmpjD1R88WI3Xz4qn created or updated.
# Room node with GUID 2_G3CYmpjD1R88WI3Xz4rZ created or updated.
# Room node with GUID 0aNC3YsFzEZf8uB9g1nSfO created or updated.
# Room node with GUID 3V7W2RscLEExyQLuCnt1oK created or updated.
# Room node with GUID 2_G3CYmpjD1R88WI3Xz4qv created or updated.
# Room node with GUID 2_G3CYmpjD1R88WI3Xz4q$ created or updated.
# Room node with GUID 2_G3CYmpjD1R88WI3Xz4qu created or updated.
# Room node with GUID 2_G3CYmpjD1R88WI3Xz4qy created or updated.
# Room node with GUID 2_G3CYmpjD1R88WI3Xz4qz created or updated.

# %%
# Funktion zum Erstellen von Material Nodes und Beziehungen in Neo4J
def create_material_nodes_and_relationships(driver, wall_topologies):
    wall_materials_dict = {}  # Dictionary zum Speichern der Materialien pro Wand

    with driver.session() as session:
        for topo in wall_topologies:
            topo_dict = Topology.Dictionary(topo)
            wall_guid = Dictionary.ValueAtKey(topo_dict, "IFC_guid")

            # Open IFC file again to extract material layers
            wall = ifc_file.by_guid(wall_guid)
            if not wall:
                print(f"Wall with GUID {wall_guid} not found.")
                continue

            material_names = []

            # Extract materials associated with the wall
            for rel in wall.HasAssociations:
                if rel.is_a('IfcRelAssociatesMaterial'):
                    material_constituent_set = rel.RelatingMaterial
                    if material_constituent_set.is_a('IfcMaterialConstituentSet'):
                        for constituent in material_constituent_set.MaterialConstituents:
                            material_name = constituent.Material.Name if constituent.Material else "No material name"
                            material_names.append(material_name)

            # Füge die Materialien dem Dictionary hinzu
            wall_materials_dict[wall_guid] = material_names

            if material_names:
                print(f"Materials for wall {wall_guid}: {material_names}")

                # Create Material nodes and relationships for each material layer
                for i, material_name in enumerate(material_names):
                    # Erstelle einen eindeutigen Materialnamen pro Wand
                    unique_material_name = f"{wall_guid}_{material_name}_{i}"

                    # Create unique Material node
                    cypher_query = """
                    MERGE (m:Material {unique_name: $unique_material_name})
                    SET m.Material = $material_name
                    """
                    session.run(cypher_query, unique_material_name=unique_material_name, material_name=material_name)

                    # Create relationship between Wall and Material
                    cypher_query = """
                    MATCH (w:Wall {guid: $wall_guid}), (m:Material {unique_name: $unique_material_name})
                    MERGE (w)-[:ConsistsOf]->(m)
                    """
                    session.run(cypher_query, wall_guid=wall_guid, unique_material_name=unique_material_name)

                    # Create a one-way InternallyConnected relationship between adjacent materials
                    if i > 0:
                        previous_material_name = f"{wall_guid}_{material_names[i-1]}_{i-1}"
                        cypher_query = """
                        MATCH (m1:Material {unique_name: $previous_material_name}), (m2:Material {unique_name: $current_material_name})
                        MERGE (m1)-[:InternallyConnected]->(m2)
                        """
                        session.run(cypher_query, previous_material_name=previous_material_name, current_material_name=unique_material_name)
            else:
                print(f"No materials found for wall {wall_guid}.")

    return wall_materials_dict  # Rückgabe des Dictionaries

# Materialien und Beziehungen zur Neo4J-Datenbank hinzufügen
wall_materials_dict = create_material_nodes_and_relationships(driver, walls_in_storey)

# Überprüfung des erstellten Dictionaries
print("Wall materials dictionary:")
for wall_guid, materials in wall_materials_dict.items():
    print(f"Wall {wall_guid}: {materials}")
# Out:
# Materials for wall 0aNC3YsFzEZf8uB9g1nSdZ: ['Hemlingby-BrandGips', 'Hemlingby-KL-Trä', 'Air Gap/Luftspalt']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSdx: ['Hemlingby-Gips', 'Hemlingby-KL-Trä', 'Hemlingby-Gips']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSdk: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSdq: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-95 Regel', 'W_Default Walls', 'Hemlingby-95 Regel', 'Hemlingby-Gips', 'Hemlingby-Gips']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSda: ['Hemlingby-Gips', 'Hemlingby-KL-Trä', 'Hemlingby-Gips']
# Materials for wall 0aNC3YsFzEZf8uB9g1nScE: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSdY: ['Hemlingby-BrandGips', 'Hemlingby-KL-Trä', 'Air Gap/Luftspalt']
# Materials for wall 0aNC3YsFzEZf8uB9g1nScD: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä', 'Air Gap/Luftspalt']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSc6: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-70 Regel CC450']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSdj: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nScR: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Gips']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSdW: ['Hemlingby-BrandGips', 'Hemlingby-KL-Trä', 'Air Gap/Luftspalt']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSc7: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-70 Regel CC450']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSdt: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-95 Regel', 'W_Default Walls', 'Hemlingby-95 Regel', 'Hemlingby-Gips', 'Hemlingby-Gips']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSd$: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nScJ: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Oorganisk gipsbaserad skiva']
# Materials for wall 0aNC3YsFzEZf8uB9g1nScV: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-195 Regel', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Oorganisk gipsbaserad skiva']
# Materials for wall 0aNC3YsFzEZf8uB9g1nScI: ['Hemlingby-Oorganisk gipsbaserad skiva', 'Hemlingby-Plywood', 'Hemlingby-Gips 12.5', 'Hemlingby-70 Regel CC450']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSc8: ['W_Trä (grå)', 'Hemlingby-Läkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSc2: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSdi: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSer: ['W_Trä (grå)', 'Hemlingby-Läkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSet: ['W_Trä (grå)', 'Hemlingby-Läkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSes: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSeq: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nShA: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nShB: ['W_Trä (grå)', 'Hemlingby-Läkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSHR: ['W_Trä (grå)', 'Hemlingby-Läkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 0aNC3YsFzEZf8uB9g1nSHQ: ['W_Skiffer', 'Hemlingby-Läkt', 'Hemlingby-Plåtläkt', 'Hemlingby-Rockwool red-air', 'Hemlingby-KL-Trä']
# Materials for wall 3V7W2RscLEExyQLuCnt1pP: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Oorganisk gipsbaserad skiva']
# Materials for wall 3V7W2RscLEExyQLuCnt1pd: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Gips']
# Materials for wall 3V7W2RscLEExyQLuCnt1pQ: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Oorganisk gipsbaserad skiva']
# Materials for wall 3V7W2RscLEExyQLuCnt1pO: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Gips']
# Materials for wall 3V7W2RscLEExyQLuCnt1pJ: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Gips']
# Materials for wall 3V7W2RscLEExyQLuCnt1pD: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-70 Regel CC450']
# Materials for wall 3V7W2RscLEExyQLuCnt1pE: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-70 Regel CC450']
# Materials for wall 3V7W2RscLEExyQLuCnt1pF: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-70 Regel CC450']
# Materials for wall 3V7W2RscLEExyQLuCnt1p0: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-70 Regel CC450']
# Materials for wall 3V7W2RscLEExyQLuCnt1oj: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-195 Regel', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Oorganisk gipsbaserad skiva']
# Materials for wall 3V7W2RscLEExyQLuCnt1oi: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Oorganisk gipsbaserad skiva']
# Materials for wall 3V7W2RscLEExyQLuCnt1ob: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Oorganisk gipsbaserad skiva']
# Materials for wall 3V7W2RscLEExyQLuCnt1oT: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Oorganisk gipsbaserad skiva']
# Materials for wall 3V7W2RscLEExyQLuCnt1oV: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Gips']
# Materials for wall 3V4w8SHAjCyBUTFZ8uhZV9: ['W_Trä (grå)', 'W_Default Walls', 'W_Default Walls', 'W_Default Walls', 'W_Trä (grå)']
# Materials for wall 3V4w8SHAjCyBUTFZ8uhZV8: ['W_Trä (grå)', 'W_Default Walls', 'W_Default Walls', 'W_Default Walls', 'W_Trä (grå)']
# Materials for wall 3V4w8SHAjCyBUTFZ8uhZ2e: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Gips']
# Materials for wall 3V4w8SHAjCyBUTFZ8uhZAP: ['Hemlingby-Oorganisk gipsbaserad skiva', 'Hemlingby-KL-Trä', 'Hemlingby-BrandGips', 'Hemlingby-BrandGips']
# Materials for wall 3V4w8SHAjCyBUTFZ8uhZox: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Plywood 12mm', 'Hemlingby-Gips']
# Materials for wall 3jY3$PuNP3MgMUTrsNt4PV: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-95 Regel']
# Materials for wall 3R2MGTuSfBAR6UB$SwSzdt: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-95 Regel']
# Materials for wall 3R2MGTuSfBAR6UB$SwSzz0: ['W_Default Walls', 'W_Default Walls', 'W_Default Walls', 'W_Default Walls']
# Materials for wall 3eHzf38IP4NBm_82GTLjrw: ['Hemlingby-Oorganisk gipsbaserad skiva', 'Hemlingby-Plywood', 'Hemlingby-Gips 12.5', 'Hemlingby-70 Regel CC450']
# Materials for wall 3KZQXY$LH1CRfttEb6cves: ['Hemlingby-Gips', 'Hemlingby-Träbaserad skiva', 'Hemlingby-70 Regel CC450', 'Hemlingby-Träbaserad skiva', 'Hemlingby-Gips']
# Materials for wall 21UIHKuuP16uj5JCg0qyOs: ['Hemlingby-Oorganisk gipsbaserad skiva', 'Hemlingby-KL-Trä', 'Hemlingby-BrandGips', 'Hemlingby-BrandGips']
#
hemlingby-95 Regel', 'Hemlingby-Plywood', 'Hemlingby-Gips']
# Wall 0pyqDFj1b8ou1XMGj0fk5w: ['Hemlingby-95 Regel', 'Hemlingby-Plywood', 'Hemlingby-Våtrumgips']
# Wall 0pyqDFj1b8ou1XMGj0fk5y: ['Hemlingby-95 Regel', 'Hemlingby-Gips', 'Hemlingby-Gips']
# Wall 0pyqDFj1b8ou1XMGj0fk3a: []
# Wall 0pyqDFj1b8ou1XMGj0ffLi: []
# Wall 0MXhwXpTnD5winnseqQxo0: []
# Wall 169UR4u8f5IfysrZg_pJqq: ['Hemlingby-Gips', 'Hemlingby-KL-Trä']
# Wall 2cZ6AGv1n9$PsnxX3G51og: []
# Wall 2aZ_Dto7fDbevo$VG0HXin: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 2aZ_Dto7fDbevo$VG0HXit: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 2aZ_Dto7fDbevo$VG0HXir: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 2aZ_Dto7fDbevo$VG0HXis: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 2aZ_Dto7fDbevo$VG0HXim: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 2aZ_Dto7fDbevo$VG0HXjB: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 2aZ_Dto7fDbevo$VG0HXiq: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 2aZ_Dto7fDbevo$VG0HXj9: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 2aZ_Dto7fDbevo$VG0HXjA: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 2aZ_Dto7fDbevo$VG0HXj8: ['Hemlingby-BrandGips', 'Hemlingby-BrandGips', 'Hemlingby-45']
# Wall 0FhCwfW0b4_fS3V96JxZJx: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-45']
# Wall 0FhCwfW0b4_fS3V96JxZGG: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-45']
# Wall 1qLd$aRfnB58C7GyIrSs_g: ['Hemlingby-Våtrumgips', 'Hemlingby-Plywood', 'Hemlingby-45']
# Wall 1qLd$aRfnB58C7GyIrSs$l: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-45']
# Wall 1qLd$aRfnB58C7GyIrSsmo: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-45']
# Wall 1qLd$aRfnB58C7GyIrSsor: ['Hemlingby-Gips', 'Hemlingby-Gips', 'Hemlingby-45']
# Wall 3xcRif4sv86voAEI35bpCh: []

# %%
import ifcopenshell
from topologicpy.Topology import Topology
from topologicpy.Dictionary import Dictionary
from neo4j import GraphDatabase

# Funktion zur Überprüfung von Berührungen zwischen Zelle und Räumen
def check_touching_spaces(cell, space_topologies):
    for space_topo in space_topologies:
        merged_topo = Topology.Merge(cell, space_topo)
        shared_faces = Topology.SharedFaces((Topology.Cells(merged_topo)[0]), (Topology.Cells(merged_topo)[1]))
        if shared_faces:
            return Dictionary.ValueAtKey(Topology.Dictionary(space_topo), "IFC_guid")
    return None

# Funktion zur Erstellung von "IsFacing"-Beziehungen in Neo4J
def add_is_facing_relationships(driver, wall_topologies, space_topologies, wall_materials_dict):
    with driver.session() as session:
        for wall_topo in wall_topologies:
            topo_dict = Topology.Dictionary(wall_topo)
            wall_guid = Dictionary.ValueAtKey(topo_dict, "IFC_guid")

            # Materialliste für die aktuelle Wand abrufen
            materials = wall_materials_dict.get(wall_guid, [])
            if not materials:
                print(f"No materials found for wall {wall_guid}.")
                continue

            # Zellen der Wandtopologie abrufen und invertieren
            wall_cells = Topology.Cells(wall_topo)[::-1]

            if len(wall_cells) < 2:
                print(f"Wall with GUID {wall_guid} does not have enough cells for processing.")
                continue

            # Erste (äußerste) und letzte (innerste) Zelle in der invertierten Liste
            outer_cell = wall_cells[0]
            inner_cell = wall_cells[-1]

            # Berührungen für äußere und innere Schicht prüfen und Beziehungen erstellen
            def create_is_facing_relationship(cell, material_name, layer_index):
                space_guid = check_touching_spaces(cell, space_topologies)
                if space_guid:
                    unique_material_name = f"{wall_guid}_{material_name}_{layer_index}"
                    cypher_query = """
                    MATCH (m:Material {unique_name: $material_name}), (r:Room {guid: $space_guid})
                    MERGE (m)-[:IsFacing]->(r)
                    """
                    session.run(cypher_query, material_name=unique_material_name, space_guid=space_guid)
                    print(f"Added IsFacing relationship between Material {unique_material_name} and Room {space_guid}")

            # Erstellen der Beziehung für die äußere Schicht (Index 0)
            create_is_facing_relationship(outer_cell, materials[0], 0)

            # Erstellen der Beziehung für die innere Schicht (Index n-1)
            create_is_facing_relationship(inner_cell, materials[-1], len(materials) - 1)

# Nutzung der Funktion zum Hinzufügen von IsFacing Beziehungen
add_is_facing_relationships(driver, walls_in_storey, spaces_in_storey, wall_materials_dict)
# Out:
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdZ_Hemlingby-BrandGips_0 and Room 2_G3CYmpjD1R88WI3Xz4q$
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdx_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nSfO
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdx_Hemlingby-Gips_2 and Room 0aNC3YsFzEZf8uB9g1nSfO
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdk_W_Skiffer_0 and Room 0uSXiavKjD892bcKOjMA$x
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdq_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nSfO
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdq_Hemlingby-Gips_6 and Room 0aNC3YsFzEZf8uB9g1nSfO
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSda_Hemlingby-Gips_2 and Room 0aNC3YsFzEZf8uB9g1nSfO
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdY_Hemlingby-BrandGips_0 and Room 0aNC3YsFzEZf8uB9g1nSfQ
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSc6_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nSfQ
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSc6_Hemlingby-70 Regel CC450_2 and Room 0aNC3YsFzEZf8uB9g1nSfO
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdj_W_Skiffer_0 and Room 0uSXiavKjD892bcKOjMA$i
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nScR_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nSca
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nScR_Hemlingby-Gips_4 and Room 0aNC3YsFzEZf8uB9g1nScx
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdW_Hemlingby-BrandGips_0 and Room 0aNC3YsFzEZf8uB9g1nSfO
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSc7_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nSfQ
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSc7_Hemlingby-70 Regel CC450_2 and Room 0aNC3YsFzEZf8uB9g1nSfO
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSdt_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4q$
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nScJ_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nScv
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nScJ_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 0aNC3YsFzEZf8uB9g1nScw
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nScV_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nScx
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nScV_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 0aNC3YsFzEZf8uB9g1nScw
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nScI_Hemlingby-Oorganisk gipsbaserad skiva_0 and Room 0aNC3YsFzEZf8uB9g1nScw
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSc2_W_Skiffer_0 and Room 0uSXiavKjD892bcKOjMA$f
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSer_W_Trä (grå)_0 and Room 0uSXiavKjD892bcKOjMA$f
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSet_W_Trä (grå)_0 and Room 0uSXiavKjD892bcKOjMA$i
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSes_W_Skiffer_0 and Room 0uSXiavKjD892bcKOjMA$i
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSeq_W_Skiffer_0 and Room 0uSXiavKjD892bcKOjMA$f
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nShA_W_Skiffer_0 and Room 0uSXiavKjD892bcKOjMA$1
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nShB_W_Trä (grå)_0 and Room 0uSXiavKjD892bcKOjMA$1
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSHR_W_Trä (grå)_0 and Room 0uSXiavKjD892bcKOjMA$x
# Added IsFacing relationship between Material 0aNC3YsFzEZf8uB9g1nSHQ_W_Skiffer_0 and Room 0uSXiavKjD892bcKOjMA$x
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pP_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1oy
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pP_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 3V7W2RscLEExyQLuCnt1ox
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pd_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1o$
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pd_Hemlingby-Gips_4 and Room 3V7W2RscLEExyQLuCnt1om
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pQ_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1oK
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pQ_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 3V7W2RscLEExyQLuCnt1oy
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pO_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1p6
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pO_Hemlingby-Gips_4 and Room 3V7W2RscLEExyQLuCnt1p6
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pJ_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pD_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pE_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1pF_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1p0_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1oK
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1oj_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1ow
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1oj_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 3V7W2RscLEExyQLuCnt1oJ
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1oi_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1oK
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1oi_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 3V7W2RscLEExyQLuCnt1oJ
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1ob_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1om
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1ob_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 3V7W2RscLEExyQLuCnt1oJ
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1oT_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1p6
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1oT_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 3V7W2RscLEExyQLuCnt1oy
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1oV_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1p6
# Added IsFacing relationship between Material 3V7W2RscLEExyQLuCnt1oV_Hemlingby-Gips_4 and Room 3V7W2RscLEExyQLuCnt1ow
# Added IsFacing relationship between Material 3V4w8SHAjCyBUTFZ8uhZV9_W_Trä (grå)_0 and Room 0uSXiavKjD892bcKOjMA$1
# Added IsFacing relationship between Material 3V4w8SHAjCyBUTFZ8uhZV9_W_Trä (grå)_4 and Room 0uSXiavKjD892bcKOjMA$4
# Added IsFacing relationship between Material 3V4w8SHAjCyBUTFZ8uhZV8_W_Trä (grå)_0 and Room 0uSXiavKjD892bcKOjMA$4
# Added IsFacing relationship between Material 3V4w8SHAjCyBUTFZ8uhZ2e_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nSca
# Added IsFacing relationship between Material 3V4w8SHAjCyBUTFZ8uhZ2e_Hemlingby-Gips_4 and Room 0aNC3YsFzEZf8uB9g1nScv
# Added IsFacing relationship between Material 3V4w8SHAjCyBUTFZ8uhZAP_Hemlingby-Oorganisk gipsbaserad skiva_0 and Room 3V7W2RscLEExyQLuCnt1oy
# Added IsFacing relationship between Material 3V4w8SHAjCyBUTFZ8uhZox_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1o$
# Added IsFacing relationship between Material 3V4w8SHAjCyBUTFZ8uhZox_Hemlingby-Gips_4 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 3jY3$PuNP3MgMUTrsNt4PV_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1om
# Added IsFacing relationship between Material 3jY3$PuNP3MgMUTrsNt4PV_Hemlingby-95 Regel_2 and Room 3V7W2RscLEExyQLuCnt1om
# Added IsFacing relationship between Material 3R2MGTuSfBAR6UB$SwSzdt_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nScx
# Added IsFacing relationship between Material 3R2MGTuSfBAR6UB$SwSzdt_Hemlingby-95 Regel_2 and Room 0aNC3YsFzEZf8uB9g1nScx
# Added IsFacing relationship between Material 3KZQXY$LH1CRfttEb6cves_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nScv
# Added IsFacing relationship between Material 3KZQXY$LH1CRfttEb6cves_Hemlingby-Gips_4 and Room 0aNC3YsFzEZf8uB9g1nScv
# Added IsFacing relationship between Material 21UIHKuuP16uj5JCg0qyOs_Hemlingby-Oorganisk gipsbaserad skiva_0 and Room 3V7W2RscLEExyQLuCnt1oJ
# Added IsFacing relationship between Material 3bmsvJtpP2Lw7375p3CrYk_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1ox
# Added IsFacing relationship between Material 0MhF3zuEzBXwC_J$8wDDII_Kulör grå_0 and Room 0uSXiavKjD892bcKOjMA$i
# Added IsFacing relationship between Material 0MhF3zuEzBXwC_J$8wDDMj_Kulör grå_0 and Room 0uSXiavKjD892bcKOjMA$f
# Added IsFacing relationship between Material 0MhF3zuEzBXwC_J$8wDFXU_Kulör grå_0 and Room 0uSXiavKjD892bcKOjMA$x
# Added IsFacing relationship between Material 0MhF3zuEzBXwC_J$8wDFXT_Kulör grå_0 and Room 0uSXiavKjD892bcKOjMA$1
# Added IsFacing relationship between Material 3cYPoAMk90vxvLVMNmmhA4_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1om
# Added IsFacing relationship between Material 3cYPoAMk90vxvLVMNmmhA6_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1o$
# Added IsFacing relationship between Material 3cYPoAMk90vxvLVMNmmhA7_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 1Xdhl_99H1LxtFe91ySc9n_Hemlingby-Oorganisk gipsbaserad skiva_0 and Room 3V7W2RscLEExyQLuCnt1oJ
# Added IsFacing relationship between Material 0HLErpwlH7GPXIOwElk89Q_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1o$
# Added IsFacing relationship between Material 1Xdhl_99H1LxtFe91ySc9m_Hemlingby-Oorganisk gipsbaserad skiva_0 and Room 3V7W2RscLEExyQLuCnt1oJ
# Added IsFacing relationship between Material 1Xdhl_99H1LxtFe91ySc9p_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1ow
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4re_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qv
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4re_Hemlingby-Gips_4 and Room 2_G3CYmpjD1R88WI3Xz4qu
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4rf_W_Default Walls_0 and Room 2_G3CYmpjD1R88WI3Xz4qv
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4qK_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4q$
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4qK_Hemlingby-Gips_4 and Room 2_G3CYmpjD1R88WI3Xz4qy
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4rl_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qu
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4rl_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 2_G3CYmpjD1R88WI3Xz4qo
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4rk_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4rZ
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4rk_Hemlingby-Gips_4 and Room 2_G3CYmpjD1R88WI3Xz4qu
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4q6_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qy
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4q6_Hemlingby-Gips_4 and Room 2_G3CYmpjD1R88WI3Xz4qy
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4qC_Hemlingby-Oorganisk gipsbaserad skiva_0 and Room 2_G3CYmpjD1R88WI3Xz4qo
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4qW_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qn
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4qW_Hemlingby-Gips_4 and Room 2_G3CYmpjD1R88WI3Xz4qv
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4qX_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qy
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4qX_Hemlingby-Gips_4 and Room 2_G3CYmpjD1R88WI3Xz4q$
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4tE_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4rZ
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4tE_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 2_G3CYmpjD1R88WI3Xz4qo
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4tC_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qz
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4tC_Hemlingby-Oorganisk gipsbaserad skiva_4 and Room 2_G3CYmpjD1R88WI3Xz4qo
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4tB_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4q$
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4tB_Hemlingby-Gips_4 and Room 2_G3CYmpjD1R88WI3Xz4qy
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4tj_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qv
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4tj_Hemlingby-70 Regel CC450_2 and Room 2_G3CYmpjD1R88WI3Xz4qv
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4tk_Hemlingby-70 Regel CC450_2 and Room 2_G3CYmpjD1R88WI3Xz4qn
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4ti_Hemlingby-70 Regel CC450_2 and Room 2_G3CYmpjD1R88WI3Xz4qv
# Added IsFacing relationship between Material 3xDiDpx$nB2hLMfVxR_vR1_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1p6
# Added IsFacing relationship between Material 3xDiDpx$nB2hLMfVxR_vR0_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1p6
# Added IsFacing relationship between Material 3xDiDpx$nB2hLMfVxR_vR0_Hemlingby-Gips_4 and Room 3V7W2RscLEExyQLuCnt1ox
# Added IsFacing relationship between Material 3xDiDpx$nB2hLMfVxR_vR3_Hemlingby-70 Regel CC450_2 and Room 3V7W2RscLEExyQLuCnt1ox
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4ql_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qn
# Added IsFacing relationship between Material 2_G3CYmpjD1R88WI3Xz4ql_Hemlingby-Gips_4 and Room 2_G3CYmpjD1R88WI3Xz4rZ
# Added IsFacing relationship between Material 3xDiDpx$nB2hLMfVxR_vLB_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1ow
# Added IsFacing relationship between Material 3xDiDpx$nB2hLMfVxR_vLB_Hemlingby-Gips_4 and Room 3V7W2RscLEExyQLuCnt1ow
# Added IsFacing relationship between Material 3xDiDpx$nB2hLMfVxR_vR2_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1oK
# Added IsFacing relationship between Material 3xDiDpx$nB2hLMfVxR_vR2_Hemlingby-Gips_4 and Room 3V7W2RscLEExyQLuCnt1p6
# Added IsFacing relationship between Material 1iMxTVpcb2rhU2MxNV6tfy_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 1iMxTVpcb2rhU2MxNV6tfy_Hemlingby-Gips_4 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 1iMxTVpcb2rhU2MxNV6toJ_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qu
# Added IsFacing relationship between Material 1iMxTVpcb2rhU2MxNV6toJ_Hemlingby-Gips_4 and Room 2_G3CYmpjD1R88WI3Xz4rZ
# Added IsFacing relationship between Material 2V0bmays95pR3l2kZG47va_Hemlingby-Gips_0 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 2V0bmays95pR3l2kZG47va_Hemlingby-Gips_3 and Room 3V7W2RscLEExyQLuCnt1o_
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAc$Gt_Hemlingby-Gips_0 and Room 2Im_2tj0r41BcHdJK8Kcz3
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAc$H9_Hemlingby-95 Regel_0 and Room 2_G3CYmpjD1R88WI3Xz4qv
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAc$Gp_Hemlingby-Oorganisk gipsbaserad skiva_0 and Room 0aNC3YsFzEZf8uB9g1nScw
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAc$Gn_Hemlingby-95 Regel_0 and Room 0aNC3YsFzEZf8uB9g1nSca
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAcyOK_Hemlingby-Gips_1 and Room 2_G3CYmpjD1R88WI3Xz4qy
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAcyD9_Hemlingby-95 Regel_0 and Room 2_G3CYmpjD1R88WI3Xz4qn
# No materials found for wall 1WQPFqcij6iRfftGTAczWd.
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAczLp_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nScv
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAc$2V_Hemlingby-95 Regel_0 and Room 3V7W2RscLEExyQLuCnt1o$
# Added IsFacing relationship between Material 0JwH4ZBer9exdsW3Xs1$At_Hemlingby-70 Regel CC450_2 and Room 2_G3CYmpjD1R88WI3Xz4rZ
# Added IsFacing relationship between Material 0JwH4ZBer9exdsW3Xs1_wG_Hemlingby-Gips_0 and Room 0aNC3YsFzEZf8uB9g1nSfO
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAcy7r_Hemlingby-Gips_0 and Room 2_G3CYmpjD1R88WI3Xz4qv
# Added IsFacing relationship between Material 1WQPFqcij6iRfftGTAcy7r_Hemlingby-BrandGips_3 and Room 2_G3CYmpjD1R88WI3Xz4q$
# No materials found for wall 2eAZvXReD5rxCsRcBVQwvx.
# No materials found for wall 2eAZvXReD5rxCsRcBVQwxO.
# Added IsFacing relationship between Material 0JwH4ZBer9exdsW3Xs1_zO_Hemlingby-BrandGips_0 and Room 2Im_2tj0r41BcHdJK8Kcz3
# Added IsFacing relationship between Material 0pyqDFj1b8ou1XMGj0fk5w_Hemlingby-95 Regel_0 and Room 3V7W2RscLEExyQLuCnt1oJ
# Added IsFacing relationship between Material 0pyqDFj1b8ou1XMGj0fk5y_Hemlingby-95 Regel_0 and Room 3V7W2RscLEExyQLuCnt1ow
# No materials found for wall 0pyqDFj1b8ou1XMGj0fk3a.
# No materials found for wall 0pyqDFj1b8ou1XMGj0ffLi.
# No materials found for wall 0MXhwXpTnD5winnseqQxo0.
# No materials found for wall 2cZ6AGv1n9$PsnxX3G51og.
# Added IsFacing relationship between Material 1qLd$aRfnB58C7GyIrSs_g_Hemlingby-45_2 and Room 2_G3CYmpjD1R88WI3Xz4qo
# Added IsFacing relationship between Material 1qLd$aRfnB58C7GyIrSs$l_Hemlingby-45_2 and Room 2_G3CYmpjD1R88WI3Xz4qz
# Added IsFacing relationship between Material 1qLd$aRfnB58C7GyIrSsmo_Hemlingby-45_2 and Room 2_G3CYmpjD1R88WI3Xz4rZ
# Added IsFacing relationship between Material 1qLd$aRfnB58C7GyIrSsor_Hemlingby-45_2 and Room 3V7W2RscLEExyQLuCnt1p6
# No materials found for wall 3xcRif4sv86voAEI35bpCh.

# %%
# Treiber schließen
driver.close()
